# %%
import pandas as pd

# %% [markdown]
# ### Read Data

# %%
df = pd.read_excel("D:/Sohaila/DPEI/Graduation project/Data/SupplyChain_Ordered_Data.xlsx")

# %% [markdown]
# ### Split Order Time Column

# %%
df[['shipping_Date','shipping_Time']] = df['shipping date (DateOrders)'].astype(str).str.split(' ', n=1, expand=True)

# %%
df[['Order_Date','Order_Time']] = df['order date (DateOrders)'].astype(str).str.split(' ', n=1, expand=True)

# %%
df.head(20)
# Out:
#    Supplier_Id  Lead_Time_Days  Raw_Material_Cost Supplier_Region  \
# 0         S063              26             295.31     Middle East
# 1         S063              26             295.31     Middle East
# 2         S063              26             295.31     Middle East
# 3         S063              26             295.31     Middle East
# 4         S063              26             295.31     Middle East
# 5         S063              26             295.31     Middle East
# 6         S063              26             295.31     Middle East
# 7         S063              26             295.31     Middle East
# 8         S063              26             295.31     Middle East
# 9         S063              26             295.31     Middle East
# 10        S063              26             295.31     Middle East
# 11        S063              26             295.31     Middle East
# 12        S063              26             295.31     Middle East
# ...

# %% [markdown]
# ### Generate column number of delay days

# %%
df['Delay_Days'] = (df['Days for shipping (real)'] - df['Days for shipment (scheduled)']).clip(lower=0)

# %% [markdown]
# ### Replace unexpected data in Customer State

# %%
postal_to_state = {
    '95758': 'CA',
    '91732': 'CA'
}

# %%
df['Customer State'] = df['Customer State'].astype(str).str.strip()
df['Customer State'] = df['Customer State'].str.replace(r'\.0$', '', regex=True) 
df['Customer State'] = df['Customer State'].replace(postal_to_state)

# %%
for value in df['Customer State'].unique():
    print(value)
# Out:
# PR
# CA
# NY
# FL
# MA
# IL
# MT
# PA
# MI
# TX
# DE
# GA
# MD
# OH
# HI
# NJ
# WI
# AZ
# CO
# MN
# NC
# NM
# OR
# SC
# VA
# UT
# WA
# KY
# WV
# RI
# CT
# LA
# TN
# DC
# ND
# MO
# IN
# ID
# NV
# KS
# AR
# OK
# AL
# IA

# %% [markdown]
# ### Replace unexpected data in Order Country

# %%
country_mapping = {
    'Afganistط¸â€‍n': 'Afghanistan',
    'Arabia Saudط¸ظ¹': 'Saudi Arabia',
    'Azerbaiyط¸â€‍n': 'Azerbaijan',
    'Bangladط£آ©s': 'Bangladesh',
    'Barط£آ©in': 'Bahrain',
    'Benط¸ظ¹n': 'Benin',
    'Butط¸â€‍n': 'Bhutan',
    'Bط£آ©lgica': 'Belgium',
    'Camerط¸â€™n': 'Cameroon',
    'Emiratos ط·طŒrabes Unidos': 'United Arab Emirates',
    'Espaط¸إ’a': 'Spain',
    'Corea del Sur': 'South Korea',
    'Etiopط¸ظ¹a': 'Ethiopia',
    'Gabط¸عکn': 'Gabon',
    'Haitط¸ظ¹': 'Haiti',
    'Hungrط¸ظ¹a': 'Hungary',
    'Irط¸â€‍n': 'Iran',
    'Japط¸عکn': 'Japan',
    'Kazajistط¸â€‍n': 'Kazakhstan',
    'Kirguistط¸â€‍n': 'Kyrgyzstan',
    'Lط¸ظ¹bano': 'Lebanon',
    'Mط£آ©xico': 'Mexico',
    'Nط¸ظ¹ger': 'Niger',
    'Omط¸â€‍n': 'Oman',
    'Pakistط¸â€‍n': 'Pakistan',
    'Panamط¸â€‍': 'Panama',
    'Papط¸â€™a Nueva Guinea': 'Papua New Guinea',
    'Paط¸ظ¹ses Bajos': 'Netherlands',
    'Perط¸â€™': 'Peru',
    'Repط¸â€™blica Centroafricana': 'Central African Republic',
    'Repط¸â€™blica Checa': 'Czech Republic',
    'Repط¸â€™blica de Gambia': 'Gambia',
    'Repط¸â€™blica del Congo': 'Republic of the Congo',
    'Repط¸â€™blica Democrط¸â€‍tica del Congo': 'Democratic Republic of the Congo',
    'Repط¸â€™blica Dominicana': 'República Dominicana',
    'Sudط¸â€‍n': 'Sudan',
    'Sudط¸â€‍n del Sur': 'South Sudan',
    'Sط¸â€‍hara Occidental': 'Western Sahara',
    'Taiwط¸â€‍n': 'Taiwan',
    'Tayikistط¸â€‍n': 'Tajikistan',
    'Turkmenistط¸â€‍n': 'Turkmenistan',
    'Turquط¸ظ¹a': 'Turkey',
    'Tط¸â€™nez': 'Tunisia',
    'Uzbekistط¸â€‍n': 'Uzbekistan'
}

# %%
df['Order Country'] = df['Order Country'].astype(str).str.strip()
df['Order Country'] = df['Order Country'].str.replace(r'[\u200b\uFEFF]', '', regex=True)
df['Order Country'] = df['Order Country'].replace(country_mapping)

# %%
for value in df['Order Country'].unique():
    print(value)
# Out:
# Indonesia
# India
# Australia
# China
# Japan
# South Korea
# Singapur
# Turkey
# Mongolia
# Estados Unidos
# Nigeria
# Democratic Republic of the Congo
# Senegal
# Marruecos
# Alemania
# Francia
# Netherlands
# Reino Unido
# Guatemala
# El Salvador
# Panama
# República Dominicana
# Venezuela
# Colombia
# Honduras
# Brasil
# Mexico
# Uruguay
# Argentina
# Cuba
# Peru
# Nicaragua
# Ecuador
# Angola
# Sudan
# Somalia
# Costa de Marfil
# Egipto
# Italia
# Spain
# Suecia
# Austria
# Canada
# Madagascar
# Argelia
# Liberia
# Zambia
# Niger
# SudAfrica
# Mozambique
# Tanzania
# Ruanda
# Israel
# Nueva Zelanda
# Bangladesh
# Tailandia
# Irak
# Saudi Arabia
# Filipinas
# Kazakhstan
# Iran
# Myanmar (Birmania)
# Uzbekistan
# Benin
# Cameroon
# Kenia
# Togo
# Ucrania
# Polonia
# Portugal
# Rumania
# Trinidad y Tobago
# Afghanistan
# Pakistan
# Vietnam
# Malasia
# Finlandia
# Rusia
# Irlanda
# Noruega
# Eslovaquia
# Belgium
# Bolivia
# Chile
# Jamaica
# Yemen
# Ghana
# Guinea
# Ethiopia
# ...

# %% [markdown]
# ### Replace unexpected data in Order State

# %%
OrderState_name_corrections = {
    'Ajmط¸â€‍n': 'Ajman',
    'Alejandrط¸ظ¹a': 'Alexandria',
    'Alsacia-Champaط¸إ’a-Ardenas-Lorena': 'Hayange-Lorraine',
    'Amapط¸â€‍': 'Amapá',
    'Amط¸â€‍n': 'Amán',
    'Andalucط¸ظ¹a': 'Andalucía',
    'Andijط¸â€‍n': 'Andiján',
    'Antioquط¸ظ¹a': 'Antioquía',
    'Anzoط¸â€‍tegui': 'Anzoátegui',
    'Aquitania-Lemosط¸ظ¹n-Poitou-Charentes': 'Aquitania-Lemosín-Poitou-Charentes',
    'Arjط¸â€‍nguelsk': 'Arjánguelsk',
    'Astanط¸â€‍': 'Astana',
    'Asunciط¸عکn': 'Asunción',
    'Atlط¸â€‍ntico': 'Atlántico',
    'Atlط¸â€‍ntida': 'Atlántida',
    'Auvernia-Rط¸عکdano-Alpes': 'Auvernia-Ródano-Alpes',
    'Bahط¸ظ¹a': 'Bahía',
    'Baluchistط¸â€‍n': 'Baluchistán',
    'Banskط¸â€‍ Bystrica': 'Banská Bystrica',
    'Bashkortostط¸â€‍n': 'Bashkortostán',
    'Berlط¸ظ¹n': 'Berlín',
    'Bingط¸ع¯l': 'Bingöl',
    'Bisط¸â€‍u': 'Bisu',
    'Biط£آ©': 'Bié',
    'Bogotط¸â€‍': 'Bogotá',
    'Bolط¸ظ¹var': 'Bolívar',
    'Borgoط¸إ’a-Franco Condado': 'Borgoña-Franco Condado',
    'Boyacط¸â€‍': 'Boyacá',
    'Bra?ov': 'Brașov',
    'Bretaط¸إ’a': 'Bretagne',
    'Bugط¸ظ¹a': 'Bugía',
    'Bط¸ظ¹o-Bط¸ظ¹o': 'Bão-Bão',
    'Bط£آ©char': 'Béchar',
    'Bط£آ©kط£آ©s': 'Békés',
    'Bط£آ©lgorod': 'Bélgorod',
    'Calabarzط¸عکn': 'Calabarzón',
    'Camagط£آ¼ey': 'Camagüey',
    'Caquetط¸â€‍': 'Caquetá',
    'Castilla y Leط¸عکn': 'Castilla y León',
    'Cataluط¸إ’a': 'Cataluña',
    'Cearط¸â€‍': 'Ceará',
    'Cerdeط¸إ’a': 'Sardegna',
    'Chauط¸ظ¹a-Uardiga': 'Uardiga',
    'Cheliط¸â€‍binsk': 'Cheliábinsk',
    'Chiriquط¸ظ¹': 'Chiriquí',
    'Chisinط¸â€‍u': 'Chișinău',
    'Chocط¸عک': 'Chocó',
    'Ciego de ط·طŒvila': 'Ciego de Ávila',
    'Ciudad de Almatأ¢â‚¬عک': 'Ciudad de Almatý',
    'Columbia britط¸â€‍nica': 'Columbia Británica',
    'Colط¸عکn': 'Colón',
    'Cortط£آ©s': 'Cortés',
    'Cuscatlط¸â€‍n': 'Cuscatlán',
    'Cط¸عکrdoba': 'Córdoba',
    'Cط£آ©lebes Central': 'Célebes Central',
    'Cط£آ©lebes Septentrional': 'Célebes Septentrional',
    'Cط£آ©lebes Suroriental': 'Célebes Suroriental',
    'Daguestط¸â€‍n': 'Daguestán',
    'Departamento Atlط¸â€‍ntico': 'Departamento Atlántico',
    'Dublط¸ظ¹n': 'Dublín',
    'Dublط¸ظ¹n del Sur': 'Dublín del Sur',
    'Durrط£آ«s': 'Durrës',
    'Dط£آ  Nang': 'Da Nang',
    'Dط£آ¼zce': 'Düzce',
    'El Aaiط¸â€™n': 'El Aaiún',
    'Emilia-Romaط¸إ’a': 'Emilia-Romaña',
    'Entre Rط¸ظ¹os': 'Entre Ríos',
    'Espط¸ظ¹ritu Santo': 'Espíritu Santo',
    'Estelط¸ظ¹': 'Estelí',
    'Fayط¸â€™n': 'Fayún',
    'Federaciط¸عکn de Bosnia y Herzegovina': 'Federación de Bosnia y Herzegovina',
    'Fez-Bulmط¸â€‍n': 'Fez-Boulmane',
    'Francisco Morazط¸â€‍n': 'Francisco Morazán',
    'Franzط¸ع¯sisch-Guayana': 'Französisch-Guayana',
    'Goiط¸â€‍s': 'Goiás',
    'Golestط¸â€‍n': 'Golestán',
    'Guantط¸â€‍namo': 'Guantánamo',
    'Guilط¸â€‍n': 'Guillén',
    'Guط¸â€‍rico': 'Guárico',
    'Gy?r': 'Győr',
    'Gط¸عکmel': 'Gümüşhane',
    'Gط£آ¼eldres': 'Gelderland',
    'Hajdط¸â€™-Bihar': 'Hajdú-Bihar',
    'Hamadط¸â€‍n': 'Hamadan',
    'Holguط¸ظ¹n': 'Holguín',
    'Hormozgط¸â€‍n': 'Hormozgán',
    'Hradec Krط¸â€‍lovط£آ©': 'Hradec Králové',
    'Isfahط¸â€‍n': 'Isfahán',
    'Jaiber Pajtunjuط¸â€‍': 'Jaiber Pajtunjwá',
    'Neuquط£آ©n': 'Neuquén',
    'Jerusalط£آ©n': 'Jerusalén',
    'Jizط¸â€‍n': 'Jizán',
    'Jorasط¸â€‍n del Sur': 'Jorasán del Sur',
    'Jorasط¸â€‍n Razavط¸ظ¹': 'Jorasán Razaví',
    'Junط¸ظ¹n': 'Junín',
    'Juzestط¸â€‍n': 'Juzestán',
    'Jط¸â€‍rkov': 'Járkov',
    'Kahramanmara?': 'Kahramanmaraş',
    'Karagandط¸â€‍': 'Karaganda',
    'Khط¸â€‍nh Hط¸ع†a': 'Khánh Hòa',
    'Kiط£ع¾n Giang': 'Kiên Giang',
    'Klaip?da': 'Klaipėda',
    'Korط£آ§ط£آ«': 'Korçë',
    'Kostanط¸â€‍i': 'Kostanái',
    'Kurdistط¸â€‍n': 'Kurdistán',
    'Kط£آ¼tahya': 'Kütahya',
    'Languedoc-Rosellط¸عکn-Mediodط¸ظ¹a-Pirineos': 'Languedoc-Roussillon-Midi-Pyrénées',
    'Leط¸عکn': 'León',
    'Lombardط¸ظ¹a': 'Lombardía',
    'Los Rط¸ظ¹os': 'Los Ríos',
    'Luzط¸عکn Central': 'Luzón Central',
    'Lط¸ظ¹bano del Norte': 'Líbano del Norte',
    'Magallanes y Antط¸â€‍rtica Chilena': 'Magallanes y Antártica Chilena',
    'Manabط¸ظ¹': 'Manabí',
    'Maraط¸إ’ط¸عکn': 'Marañón',
    'Markazط¸ظ¹': 'Markazí',
    'Marط¸ظ¹tima': 'Marítima',
    'Mazandarط¸â€‍n': 'Mazandarán',
    'Michoacط¸â€‍n': 'Michoacán',
    'Monseط¸إ’or Nouel': 'Monseñor Nouel',
    'Moscط¸â€™': 'Moscú',
    'Mط£آ©rida': 'Mérida',
    'Mط£آ©xico': 'México',
    'Namangط¸â€‍n': 'Namangán',
    'Nariط¸إ’o': 'Nariño',
    'Normandط¸ظ¹a': 'Normandía',
    'Norte-Paso de Calais-Picardط¸ظ¹a': 'Norte-Paso de Calais-Picardía',
    'Nuevo Leط¸عکn': 'Nuevo León',
    'Nuevo Mط£آ©xico': 'Nuevo México',
    'Nzط£آ©rط£آ©korط£آ©': 'Nzérékoré',
    'Nط¸ظ¹ger': 'Níger',
    'Nط¸ظ¹nive': 'Nínive',
    'Nط¸عکvgorod': 'Nizhní Novgorod',
    'Oregط¸عکn': 'Oregón',
    'Orط¸â€‍n': 'Orán',
    'Ouط£آ©mط£آ©': 'Ouémé',
    'Panamط¸â€‍': 'Panamá',
    'Paranط¸â€‍': 'Paraná',
    'Paraط¸ظ¹ba': 'Paraíba',
    'Parط¸â€‍': 'Pará',
    'Paysandط¸â€™': 'Paysandú',
    'Paط¸ظ¹s Vasco': 'País Vasco',
    'Paط¸ظ¹ses del Loira': 'Países del Loira',
    'Pekط¸ظ¹n': 'Pekín',
    'Piauط¸ظ¹': 'Piauí',
    'Pinar del Rط¸ظ¹o': 'Pinar del Río',
    'Potosط¸ظ¹': 'Potosí',
    'Prefectura de Vientiط¸â€‍n': 'Prefectura de Vientián',
    'Puerto Saط¸ظ¹d': 'Port Said',
    'Qazvط¸ظ¹n': 'Qazvín',
    'Querط£آ©taro': 'Querétaro',
    'Quindط¸ظ¹o': 'Quindío',
    'Rabat-Salط£آ©-Zemur-Zaer': 'Rabat-Salé-Zemmour-Zaer',
    'Rajastط¸â€‍n': 'Rajasthan',
    'Rondط£آ´nia': 'Rondônia',
    'Rangط¸â€™n': 'Rangún',
    'Ras al-Jaima': 'Ras al-Jaima',
    'Regiط¸عکn Capital': 'Región Capital',
    'Rط¸ظ¹o de Janeiro': 'Río de Janeiro',
    'Rط¸ظ¹o Grande del Norte': 'Río Grande del Norte',
    'Rط¸ظ¹o Negro': 'Río Negro',
    'Rط¸ظ¹os': 'Ríos',
    'San Cristط¸عکbal': 'San Cristóbal',
    'San Luis Potosط¸ظ¹': 'San Luis Potosí',
    'San Pedro de Macorط¸ظ¹s': 'San Pedro de Macorís',
    'Sancti Spط¸ظ¹ritus': 'Sancti Spíritus',
    'Semnط¸â€‍n': 'Semnan',
    'Setط¸â€™bal': 'Setúbal',
    'Seط¸â€™l': 'Seúl',
    'Shanghط¸â€‍i': 'Shanghái',
    'Shkodط£آ«r': 'Shkodër',
    'Sistط¸â€‍n y Baluchistط¸â€‍n': 'Sistán y Baluchistán',
    'Sofط¸ظ¹a-Ciudad': 'Sofía-Ciudad',
    'Stط¸â€‍vropol': 'Stávropol',
    'Surjandarط¸ظ¹n': 'Surjandarán',
    'Sط¸â€¦o Paulo': 'São Paulo',
    'Sط¸ع¯dermanland': 'Södermanland',
    'T?nh C?n Th?': 'Tỉnh Cần Thơ',
    'Taipط£آ©i': 'Taipéi',
    'Tarapacط¸â€‍': 'Tarapacá',
    'Teherط¸â€‍n': 'Teherán',
    'Ternط¸عکpil': 'Ternopil',
    'Th? Dط£آ´ Hط£آ  N?i': 'Thủ Đô Hà Nội',
    'Thiط£آ¨s': 'Thiès',
    'Tط¸â€‍chira': 'Táchira',
    'Tط¸â€‍nger-Tetuط¸â€‍n': 'Tánger-Tetuán',
    'Tط¸â€™nez': 'Túnez',
    'Ulط¸â€‍n Bator': 'Ulan Bator',
    'Umbrط¸ظ¹a': 'Umbría',
    'Vallط£آ©e du Bandama': 'Vallée du Bandama',
    'Valparaط¸ظ¹so': 'Valparaíso',
    'Vladط¸ظ¹mir': 'Vladímir',
    'Vlorط£آ«': 'Vlorë',
    'Vorط¸عکnezh': 'Voróonezh',
    'Vط¸â€ rmland': 'Värmland',
    'Vط¸â€ stra Gط¸ع¯taland': 'Västra Götaland',
    'Vط¸ظ¹nnytsia': 'Vinnytsia',
    'Vط£آ¢lcea': 'Vâlcea',
    'Vط£آ©neto': 'Veneto',
    'Yucatط¸â€‍n': 'Yucatán',
    'Zanyط¸â€‍n': 'Zanjan',
    'Zhytط¸عکmyr': 'Zhytomyr',
    'Zط¸â€™rich': 'Zürich',
    'ط¸آ¹iauliai': 'Šiauliai',
    'ط·آ§anakkale': 'Çanakkale',
    'ط·آ©quateur': 'Équateur',
    'ط·آ¹stط¸ظ¹ nad Labem': 'České nad Labem',
    'ط¹ع©ilina': 'Žilina'
}

# %%
df['Order State'] = df['Order State'].astype(str).str.strip()
df['Order State'] = df['Order State'].str.replace(r'[\u200b\uFEFF]', '', regex=True)
df['Order State'] = df['Order State'].replace(OrderState_name_corrections)

# %%
for value in df['Order State'].unique():
    print(value)
# Out:
# Java Occidental
# Rajasthan
# Queensland
# Guangdong
# Tokio
# Célebes Septentrional
# Maharashtra
# Seúl
# Madhya Pradesh
# Victoria
# Australia Occidental
# Guangxi
# Delhi
# Gansu
# Singapur
# Karnataka
# Nueva Gales del Sur
# Sumatra Septentrional
# Territorio de la Capital Australiana
# Zhejiang
# Uttar Pradesh
# Bursa
# Australia del Sur
# Estambul
# Ulan Bator
# Washington
# California
# Kansas
# Cross River
# Kinshasa
# Dakar
# Gran Casablanca
# Renania del Norte-Westfalia
# Isla de Francia
# Países del Loira
# Groningen
# Inglaterra
# Hayange-Lorraine
# Provenza-Alpes-Costa Azul
# Guatemala
# San Salvador
# Chiriquí
# Santo Domingo
# Zulia
# Risaralda
# Francisco Morazán
# Bahía
# Distrito Federal
# Jalisco
# Puebla
# São Paulo
# Montevideo
# Buenos Aires
# Paraná
# Camagüey
# Las Tunas
# Nayarit
# Panamá
# México
# Alagoas
# Minas Gerais
# Santiago de Cuba
# Cortés
# Lima (ciudad)
# Holguín
# Veracruz
# Managua
# Tabasco
# Ceará
# Isla de la Juventud
# Chimaltenango
# ...

# %% [markdown]
# ### Replace unexpected data in Order City

# %%
city_corrections = {
    "Seط¸â€™l": "Seoul",
    "Sط¸â€¦o Paulo": "São Paulo",
    "Camagط£آ¼ey": "Camagüey",
    "Maceiط¸عک": "Maceió",
    "Holguط¸ظ¹n": "Holguín",
    "Quixadط¸â€‍": "Quixadá",
    "Leط¸عکn": "León",
    "Cط¸عکrdoba": "Córdoba",
    "Jerusalط£آ©n": "Jerusalén",
    "Rangط¸â€™n": "Rangún",
    "Kط£آ¼tahya": "Kütahya",
    "Namangط¸â€‍n": "Namangán",
    "Brasط¸ظ¹lia": "Brasília",
    "Santarط£آ©m": "Santarém",
    "Querط£آ©taro": "Querétaro",
    "Balneط¸â€‍rio Camboriط¸â€™": "Balneário Camboriú",
    "Maturط¸ظ¹n": "Maturín",
    "ط·طŒguas Lindas de Goiط¸â€‍s": "Águas Lindas de Goiás",
    "Bogotط¸â€‍": "Bogotá",
    "Shanghط¸â€‍i": "Shanghai",
    "Mauط¸â€‍": "Mauá",
    "Lط¸â€‍zaro Cط¸â€‍rdenas": "Lázaro Cárdenas",
    "Dublط¸ظ¹n": "Dublín",
    "Pinar del Rط¸ظ¹o": "Pinar del Río",
    "Araranguط¸â€‍": "Araranguá",
    "Juط¸â€‍rez": "Juárez",
    "Santana de Parnaط¸ظ¹ba": "Santana de Parnaíba",
    "Macapط¸â€‍": "Macapá",
    "Guantط¸â€‍namo": "Guantánamo",
    "Pekط¸ظ¹n": "Pekín",
    "Berlط¸ظ¹n": "Berlín",
    "Cheliط¸â€‍binsk": "Chelyabinsk",
    "Astracط¸â€‍n": "Astracán",
    "Teresط¸عکpolis": "Teresópolis",
    "Astanط¸â€‍": "Astana",
    "Sط¸â€¦o Bernardo do Campo": "São Bernardo do Campo",
    "San Martط¸ظ¹n": "San Martín",
    "Ocotlط¸â€‍n": "Ocotlán",
    "Fayط¸â€™n": "Fayón",
    "Budط£آ«nnovsk": "Budënnovsk",
    "Zanyط¸â€‍n": "Zanjan",
    "Jط¸â€‍rkov": "Järkov",
    "Culiacط¸â€‍n": "Culiacán",
    "Vط¸ظ¹nnytsia": "Vinnytsia",
    "Medellط¸ظ¹n": "Medellín",
    "Ribeirط¸â€¦o Preto": "Ribeirão Preto",
    "Estelط¸ظ¹": "Estelí",
    "Coyoacط¸â€‍n": "Coyoacán",
    "Soledad Dط¸ظ¹ez Gutiط£آ©rrez": "Soledad Díez Gutiérrez",
    "Francisco Beltrط¸â€¦o": "Francisco Beltrão",
    "Araguaط¸ظ¹na": "Araguaína",
    "San Josط£آ© de las Lajas": "San José de las Lajas",
    "Gط¸عکmez Palacio": "Gómez Palacio",
    "Eunط¸â€‍polis": "Eunápolis",
    "Anط¸â€‍polis": "Anápolis",
    "Joط¸â€¦o Pessoa": "João Pessoa",
    "Jizط¸â€‍n": "Jizán",
    "San Francisco del Rincط¸عکn": "San Francisco del Rincón",
    "Heroica Zitط¸â€‍cuaro": "Heroica Zitácuaro",
    "San Cristط¸عکbal de Las Casas": "San Cristóbal de Las Casas",
    "Tuxtla Gutiط£آ©rrez": "Tuxtla Gutiérrez",
    "Mossorط¸عک": "Mossoró",
    "Gonaط£آ¯ves": "Gonaïves",
    "Sancti Spط¸ظ¹ritus": "Sancti Spíritus",
    "Acuط¸إ’a": "Acuña",
    "Itaط¸â€™na": "Itaúna",
    "El Limط¸عکn": "El Limón",
    "Colط¸عکn": "Colón",
    "Sط¸â€¦o Gonط£آ§alo": "São Gonçalo",
    "Consolaciط¸عکn del Sur": "Consolación del Sur",
    "Mط£آ©rida": "Mérida",
    "Aط£آ§u": "Açu",
    "Maringط¸â€‍": "Maringá",
    "San Luis Potosط¸ظ¹": "San Luis Potosí",
    "Antiguo Cuscatlط¸â€‍n": "Antiguo Cuscatlán",
    "Jequiط£آ©": "Jequié",
    "Banط¸ظ¹": "Baní",
    "Amatitlط¸â€‍n": "Amatitlán",
    "Simط¸عˆes Filho": "Simões Filho",
    "Chapecط¸عک": "Chapecó",
    "Paysandط¸â€™": "Paysandú",
    "Jataط¸ظ¹": "Jataí",
    "Itajaط¸ظ¹": "Itajaí",
    "Sط¸â€¦o Josط£آ© dos Campos": "São José dos Campos",
    "Ibiط¸â€™na": "Ibiúna",
    "Araط£آ§atuba": "Araçatuba",
    "Cancط¸â€™n": "Cancún",
    "Ji-Paranط¸â€‍": "Ji-Paraná",
    "Araط£آ§atuba": "Araçatuba",
    "Camaط£آ§ari": "Camaçari",
    "Tupط¸â€¦": "Tupã",
    "Grajaط¸â€™": "Grajaú",
     "Vladط¸ظ¹mir": "Vladimir",
    "Bط£آ©lgorod": "Belgorod",
    "Arraijط¸â€‍n": "Arraiján",
    "Concepciط¸عکn del Uruguay": "Concepción del Uruguay",
    "Viط¸إ’a del Mar": "Viña del Mar",
    "Apatzingط¸â€‍n de la Constituciط¸عکn": "Apatzingán de la Constitución",
    "Tecomط¸â€‍n": "Tecomán",
    "Vitط¸عکria": "Vitória",
    "San Andrط£آ©s Tuxtla": "San Andrés Tuxtla",
    "Jamundط¸ظ¹": "Jamundí",
    "Sط¸â€¦o Miguel dos Campos": "São Miguel dos Campos",
    "Montrط£آ©al": "Montréal",
    "Lambarط£آ©": "Lambaré",
    "Boa Esperanط£آ§a": "Boa Esperança",
    "Valparaط¸ظ¹so": "Valparaíso",
    "Nicolط¸â€‍s Romero": "Nicolás Romero",
    "Guaratinguetط¸â€‍": "Guaratinguetá",
    "Teherط¸â€‍n": "Teherán",
    "Sط¸â€¦o Luط¸ظ¹s": "São Luís",
    "Guzmط¸â€‍n": "Guzmán",
    "Caط£آ§ador": "Caçador",
    "Ibiritط£آ©": "Ibirité",
    "Lenط£آ§ط¸عکis Paulista": "Lençóis Paulista",
    "Hamadط¸â€‍n": "Hamadan",
    "Josط£آ© Bonifط¸â€‍cio": "José Bonifácio",
    "Bolط¸ظ¹var": "Bolívar",
    "Cuautitlط¸â€‍n": "Cuautitlán",
    "Ibaguط£آ©": "Ibagué",
    "Ijuط¸ظ¹": "Ijuí",
    "Petrط¸عکpolis": "Petrópolis",
    "Cط¸â€‍rdenas": "Cárdenas",
     "Tط¸â€™nez": "Ténès",
    "Chisinط¸â€‍u": "Chișinău",
    "Ocaط¸إ’a": "Ocana",
    "Sahuayo de Josط£آ© Marط¸ظ¹a Morelos": "Sahuayo de José María Morelos",
    "Goiط£آ¢nia": "Goiânia",
    "Fresnillo de Gonzط¸â€‍lez Echeverrط¸ظ¹a": "Fresnillo de González Echeverría",
    "Garza Garcط¸ظ¹a": "Garza García",
    "Paranaguط¸â€‍": "Paranaguá",
    "Hradec Krط¸â€‍lovط£آ©": "Hradec Králové",
    "Presidencia Roque Sط¸â€‍enz Peط¸إ’a": "Presidencia Roque Sáenz Peña",
    "Tianguط¸â€‍": "Tianguá",
    "Araucط¸â€‍ria": "Araucária",
    "Bahط¸ظ¹a Blanca": "Bahía Blanca",
    "Cumanط¸â€‍": "Cumaná",
    "Chillط¸â€‍n": "Chillán",
    "Valparaط¸ظ¹so de Goiط¸â€‍s": "Valparaíso de Goiás",
    "Neuquط£آ©n": "Neuquén",
    "Kostanط¸â€‍i": "Kostanai",
     "Braganط£آ§a Paulista": "Bragança Paulista",
    "Sumarط£آ©": "Sumaré",
    "Rolط£آ¢ndia": "Rolândia",
    "Criciط¸â€™ma": "Criciúma",
    "Sط¸â€¦o Pedro da Aldeia": "São Pedro da Aldeia",
    "Vorط¸عکnezh": "Voronezh",
    "Vitط¸عکria de Santo Antط¸â€¦o": "Vitória de Santo Antão",
    "Gravataط¸ظ¹": "Gravatá",
    "Copiapط¸عک": "Copiapó",
    "Taubatط£آ©": "Taubaté",
    "Sط¸â€¦o Vicente": "São Vicente",
    "Cubatط¸â€¦o": "Cubatão",
    "Oriximinط¸â€‍": "Oriximiná",
    "Bagط£آ©": "Bagé",
    "Cط¸â€™a": "Caia",
    "ط·آ¹stط¸ظ¹ nad Labem": "Ústí nad Labem",
    "Teziutlط¸â€‍n": "Teziutlán",
    "Patrocط¸ظ¹nio": "Patrocínio",
    "Quibdط¸عک": "Quibdó",
    "Uberlط£آ¢ndia": "Uberlândia",
    "Niterط¸عکi": "Niterói",
    "Rط¸ظ¹o Bravo": "Río Bravo",
    "Vitط¸عکria da Conquista": "Vitória da Conquista",
    "Cط¸â€‍rtama": "Cártama",
    "Guarujط¸â€‍": "Guarujá",
    "Zhytط¸عکmyr": "Zhytomyr",
    "Gط£آ¼nzburg": "Günzburg",
    "Bugط¸ظ¹a": "Bugía",
    "Bisط¸â€‍u": "Bissau",
    "Le Prط£آ©-Saint-Gervais": "Le Pré-Saint-Gervais",
    "Lط¸ظ¹bano": "Líbano",
    "Divinط¸عکpolis": "Divinópolis",
    "Cassilط£آ¢ndia": "Cassilândia",
    "Palhoط£آ§a": "Palhoça",
}

# %%
df['Order City'] = df['Order City'].astype(str).str.strip()
df['Order City'] = df['Order City'].str.replace(r'[\u200b\uFEFF]', '', regex=True)
df['Order City'] = df['Order City'].replace(city_corrections)

# %%
for value in df['Order City'].unique():
    print(value)
# Out:
# Bekasi
# Bikaner
# Townsville
# Toowoomba
# Guangzhou
# Tokio
# Manado
# Sangli
# Seoul
# Jabalpur
# Geelong
# Brisbane
# Mandurah
# Guilin
# Delhi
# Suzhou
# Singapur
# Hubli
# Wollongong
# Medan
# Canberra
# Bangalore
# Yiwu
# Mirzapur
# Bursa
# Murray Bridge
# Kartal
# Ulan Bator
# Estambul
# Raipur
# Pasco
# Los Angeles
# San Francisco
# Overland Park
# Ugep
# Kinshasa
# Dakar
# Casablanca
# Dortmund
# Drancy
# Nantes
# Groningen
# Gateshead
# Eastbourne
# Hayange
# Portsmouth
# Gelsenkirchen
# Nice
# Petapa
# Mejicanos
# David
# Santo Domingo
# Cabimas
# Dos Quebradas
# Ilopango
# Tegucigalpa
# Juazeiro
# Mexico City
# Tlaquepaque
# Puebla
# São Paulo
# Montevideo
# Buenos Aires
# Barueri
# Arapongas
# Camagüey
# Las Tunas
# Tepic
# San Miguelito
# Ixtapaluca
# Maceió
# Belo Horizonte
# Santiago de Cuba
# San Pedro Sula
# Lima
# Holguín
# Orizaba
# Managua
# Villahermosa
# Quixadá
# Mixco
# Nueva Gerona
# Chimaltenango
# Villa Nueva
# Quito
# Valle de La Pascua
# Cotia
# ...

# %% [markdown]
# ### Upload Data

# %%
df.to_excel("D:/Sohaila/DPEI/Graduation project/Data/SupplyChain_Ordered_Data_Cleaned.xlsx", index=False)
